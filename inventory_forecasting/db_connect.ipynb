# %%
pip install mysql-connector-python pandas
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: pandas in c:\users\valak\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\valak\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\valak\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\valak\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\valak\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\valak\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading mysql_connector_python-9.5.0-cp312-cp312-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.5 MB 540.5 kB/s eta 0:00:30
#    - -------------------------------------- 0.8/16.5 MB 621.2 kB/s eta 0:00:26
#    - -------------------------------------- 0.8/16.5 MB 621.2 kB/s eta 0:00:26
#    --- ------------------------------------ 1.3/16.5 MB 789.0 kB/s eta 0:00:20
#    --- ------------------------------------ 1.3/16.5 MB 789.0 kB/s eta 0:00:20
#    --- ------------------------------------ 1.6/16.5 MB 830.1 kB/s eta 0:00:18
#    ---- ----------------------------------- 1.8/16.5 MB 890.6 kB/s eta 0:00:17
#    ----- ---------------------------------- 2.1/16.5 MB 869.7 kB/s eta 0:00:17
#    ----- ---------------------------------- 2.1/16.5 MB 869.7 kB/s eta 0:00:17
#    ----- ---------------------------------- 2.4/16.5 MB 860.2 kB/s eta 0:00:17
#    ----- ---------------------------------- 2.4/16.5 MB 860.2 kB/s eta 0:00:17
#    ----- ---------------------------------- 2.4/16.5 MB 860.2 kB/s eta 0:00:17
#    ------ --------------------------------- 2.6/16.5 MB 762.5 kB/s eta 0:00:19
#    ------ --------------------------------- 2.6/16.5 MB 762.5 kB/s eta 0:00:19
#    ------ --------------------------------- 2.9/16.5 MB 732.5 kB/s eta 0:00:19
#    ------- -------------------------------- 3.1/16.5 MB 750.2 kB/s eta 0:00:18
#    ------- -------------------------------- 3.1/16.5 MB 750.2 kB/s eta 0:00:18
#    -------- ------------------------------- 3.7/16.5 MB 790.1 kB/s eta 0:00:17
#    -------- ------------------------------- 3.7/16.5 MB 790.1 kB/s eta 0:00:17
#    --------- ------------------------------ 3.9/16.5 MB 798.9 kB/s eta 0:00:16
#    ---------- ----------------------------- 4.2/16.5 MB 801.3 kB/s eta 0:00:16
#    ---------- ----------------------------- 4.2/16.5 MB 801.3 kB/s eta 0:00:16
#    ---------- ----------------------------- 4.5/16.5 MB 806.0 kB/s eta 0:00:15
#    ----------- ---------------------------- 4.7/16.5 MB 817.1 kB/s eta 0:00:15
#    ------------ --------------------------- 5.0/16.5 MB 822.8 kB/s eta 0:00:15
#    ------------ --------------------------- 5.0/16.5 MB 822.8 kB/s eta 0:00:15
#    ------------ --------------------------- 5.0/16.5 MB 822.8 kB/s eta 0:00:15
#    ------------ --------------------------- 5.2/16.5 MB 777.4 kB/s eta 0:00:15
#    ------------ --------------------------- 5.2/16.5 MB 777.4 kB/s eta 0:00:15
#    ------------- -------------------------- 5.5/16.5 MB 778.5 kB/s eta 0:00:15
#    ------------- -------------------------- 5.5/16.5 MB 778.5 kB/s eta 0:00:15
#    ------------- -------------------------- 5.8/16.5 MB 770.9 kB/s eta 0:00:14
#    -------------- ------------------------- 6.0/16.5 MB 773.7 kB/s eta 0:00:14
#    -------------- ------------------------- 6.0/16.5 MB 773.7 kB/s eta 0:00:14
#    --------------- ------------------------ 6.3/16.5 MB 770.1 kB/s eta 0:00:14
#    --------------- ------------------------ 6.3/16.5 MB 770.1 kB/s eta 0:00:14
#    --------------- ------------------------ 6.6/16.5 MB 762.6 kB/s eta 0:00:14
#    ---------------- ----------------------- 6.8/16.5 MB 772.4 kB/s eta 0:00:13
#    ---------------- ----------------------- 6.8/16.5 MB 772.4 kB/s eta 0:00:13
#    ----------------- ---------------------- 7.1/16.5 MB 770.7 kB/s eta 0:00:13
#    ----------------- ---------------------- 7.1/16.5 MB 770.7 kB/s eta 0:00:13
#    ----------------- ---------------------- 7.3/16.5 MB 767.8 kB/s eta 0:00:12
#    ------------------ --------------------- 7.6/16.5 MB 775.2 kB/s eta 0:00:12
#    ------------------- -------------------- 7.9/16.5 MB 780.9 kB/s eta 0:00:12
#    ------------------- -------------------- 8.1/16.5 MB 788.9 kB/s eta 0:00:11
#    -------------------- ------------------- 8.4/16.5 MB 800.1 kB/s eta 0:00:11
#    --------------------- ------------------ 8.9/16.5 MB 830.0 kB/s eta 0:00:10
#    ---------------------- ----------------- 9.2/16.5 MB 840.0 kB/s eta 0:00:09
#    ---------------------- ----------------- 9.4/16.5 MB 852.2 kB/s eta 0:00:09
#    ----------------------- ---------------- 9.7/16.5 MB 860.4 kB/s eta 0:00:08
#    ------------------------ --------------- 10.2/16.5 MB 884.2 kB/s eta 0:00:08
#    ------------------------- -------------- 10.5/16.5 MB 892.6 kB/s eta 0:00:07
#    -------------------------- ------------- 10.7/16.5 MB 900.8 kB/s eta 0:00:07
#    --------------------------- ------------ 11.3/16.5 MB 922.3 kB/s eta 0:00:06
#    --------------------------- ------------ 11.5/16.5 MB 928.4 kB/s eta 0:00:06
#    ---------------------------- ----------- 11.8/16.5 MB 938.0 kB/s eta 0:00:06
#    ----------------------------- ---------- 12.1/16.5 MB 947.2 kB/s eta 0:00:05
#    ----------------------------- ---------- 12.3/16.5 MB 952.7 kB/s eta 0:00:05
#    ------------------------------ --------- 12.6/16.5 MB 960.4 kB/s eta 0:00:05
#    ------------------------------- -------- 12.8/16.5 MB 966.7 kB/s eta 0:00:04
#    ------------------------------- -------- 13.1/16.5 MB 971.7 kB/s eta 0:00:04
#    --------------------------------- ------ 13.6/16.5 MB 981.2 kB/s eta 0:00:03
#    --------------------------------- ------ 13.9/16.5 MB 990.2 kB/s eta 0:00:03
#    ---------------------------------- ----- 14.2/16.5 MB 992.4 kB/s eta 0:00:03
#    ---------------------------------- ----- 14.4/16.5 MB 998.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 14.7/16.5 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 14.9/16.5 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------ --- 15.2/16.5 MB 1.0 MB/s eta 0:00:02
#    ------------------------------------- -- 15.5/16.5 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 15.7/16.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 1.0 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd

# Database connection
conn = mysql.connector.connect(
    host="projects.datamites.com",
    user="dm_usdata_sql",
    password="37z<49REb&mKnl4AV!vJ",
    database="project_service_data",
    port=3306
)

print("Database connected successfully")

# Fetch data from table
query = "SELECT * FROM service_data"
df = pd.read_sql(query, conn)

# Show first 5 rows
print(df.head())

# Save data to CSV
df.to_csv("service_data.csv", index=False)
print("Data saved as service_data.csv")

# Close connection
conn.close()
print("Database connection closed")
# Out:
# Database connected successfully
# C:\Users\valak\AppData\Local\Temp\ipykernel_18156\2003979455.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#   invoice_date job_card_date business_partner_name  vehicle_no  \
# 0     30-05-17      30-05-17        shivXXXXXXXXXX  KA03MFXXXX
# 1     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
# 2     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
# 3     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
# 4     02-06-17      31-05-17        KIRAXXXXXXXXXX  KA53ESXXXX
#
#               vehicle_model current_km_reading invoice_line_text
# 0  BAJAJ AVENGER STREET 220              50000        ENGINE OIL
# 1       BAJAJ PULSAR NS 200                758        ENGINE OIL
# 2       BAJAJ PULSAR NS 200                758            POLISH
# 3       BAJAJ PULSAR NS 200                758       CONSUMABLES
# 4       BAJAJ PULSAR NS 200                758       COOLANT OIL
# Data saved as service_data.csv
# Database connection closed
